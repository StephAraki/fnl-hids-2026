# %% [markdown]
# # CTDC Skill Exploration
# **Date:** June 11, 2026
# **Author:** Stephanie Araki
# **Purpose:** Explore what the CTDC Claude skill knows and identify gaps
#
# ## Objective
# Use the CTDC skill with an AI model to answer CTDC questions and document what works, what doesn't and any other observations.

# %%
# Environment setup
import os
from dotenv import load_dotenv

load_dotenv()

# Verify API key is loaded
openai_key = os.getenv("OPENAI_API_KEY")
print("OpenAI key loaded:", "Yes" if openai_key else "NO - check .env file")
# Out:
# OpenAI key loaded: Yes

# %% [markdown]
# ### Load CTDC skill content

# %%
from openai import OpenAI
client = OpenAI()

# Load CTDC skill
with open("../skills/ctdc-claude-skill/SKILL.md", "r") as f:
    skill_content = f.read()

# Test
response = client.chat.completions.create(
    # model="gpt-4o",                   ## tried this one first
    model="gpt-3.5-turbo",              ## tried this one second, but did not fix quota issue
    messages=[
        #{"role": "system", "content": skill_content},
        {"role": "user", "content": "Say hello in one sentence"}
    ]
)

print("Response from CTDC skill:")
print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[9], line 9
#       5 with open("../skills/ctdc-claude-skill/SKILL.md", "r") as f:
#       6     skill_content = f.read()
#       7
#       8 # Test
# ----> 9 response = client.chat.completions.create(
#      10     model="gpt-3.5-turbo",
#      11     messages=[
#      12         #{"role": "system", "content": skill_content},
#
# File ~/Projects/hids-fnlcr-2026/venv/lib/python3.12/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# ...
